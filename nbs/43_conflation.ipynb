# %% [markdown]
# # `Conflation`

# %%
#| default_exp conflate

# %%
#| export
import numpy as np, pandas as pd, scipy.sparse as sp, torch, json, os, re
import matplotlib.pyplot as plt

from tqdm.auto import tqdm
from typing import Optional, Union, Dict, List
from IPython.display import display
from xclib.utils.sparse import retain_topk
from collections import Counter

# %% [markdown]
# ## Helper functions

# %%
#| export
def display_similar_items(matrix:sp.csr_matrix, n_data:Optional[int]=10, n_view_data:Optional[int]=20, 
                          seed:Optional[int]=1000):
    np.random.seed(seed)
    rnd_idx = np.random.permutation(matrix.shape[0])[:n_data]
    
    outputs = list()
    for idx in rnd_idx:
        sort_idx = np.argsort(matrix[idx].data)[:-n_view_data:-1]
        scores = matrix[idx].data[sort_idx]
        indices = matrix[idx].indices[sort_idx]
        labels = [meta_info['text'][i] for i in indices]
        o = {
            "Substring": meta_info['text'][idx],
            "Predictions": [(x, float(y)) for x,y in zip(labels, scores)]
        }
        outputs.append(o)
    return outputs

# %%
#| export
def get_conflated_text(clusters:List, meta_info:Dict):
    texts = [[meta_info["text"][i] for i in c] for c in clusters]
    idx = np.argsort([len(c) for c in clusters])[::-1]
    return [texts[i] for i in idx]

# %%
#| export
class Operations:

    @staticmethod
    def compute_yty(mat:sp.csr_matrix, bsz:Optional[int]=1000, normalize=True):
        mat_t = mat.transpose()
        out = sp.vstack([mat[i:i+bsz]@mat_t for i in tqdm(range(0, mat.shape[0], bsz))])
        def invert(a):
            return np.divide(1.0, a, out=np.zeros_like(a), where=a!=0)
        return out.multiply(invert(out.sum(axis=1))).multiply(invert(out.sum(axis=0))).tocsr()

    @staticmethod
    def minimum(matrix:sp.csr_matrix):
        return np.array([matrix.data[i:j].min() for i,j in zip(matrix.indptr, matrix.indptr[1:])])

    @staticmethod
    def min_clamp(matrix:sp.csr_matrix, value:float, inplace:Optional[bool]=True):
        if not inplace:
            matrix = matrix.copy()
        matrix.data[matrix.data <= value] = 0
        matrix.eliminate_zeros()
        return matrix

    @staticmethod
    def max_clamp(matrix:sp.csr_matrix, value:float, inplace:Optional[bool]=True):
        if not inplace:
            matrix = matrix.copy()
        matrix.data[matrix.data >= value] = 0
        matrix.eliminate_zeros()
        return matrix

    @staticmethod
    def diff_threshold(matrix:sp.csr_matrix, value:float):
        for i,j in zip(matrix.indptr, matrix.indptr[1:]):
            data = matrix.data[i:j]
            if len(data):
                idx = np.where(data.max() - data > value)[0]
                data[idx] = 0.0
                matrix.data[i:j] = data
        matrix.eliminate_zeros()
        return matrix

    @staticmethod
    def get_clusters(groups:np.array, lbl_idx:Optional[np.array]=None):
        lbl_idx = np.arange(groups.shape[0]) if lbl_idx is None else lbl_idx
        assert groups.shape == lbl_idx.shape, "`groups` and `lbl_idx` must have the same shape."
        clusters = dict()
        for k,v in zip(groups, lbl_idx): 
            clusters.setdefault(k, []).append(v)
        return list(clusters.values())

# %%
#| export
class Filter:

    @staticmethod
    def from_max_size(clusters:List, size:int):
        return [c for c in clusters if len(c) < size]

    @staticmethod
    def from_min_size(clusters:List, size:int):
        return [c for c in clusters if len(c) > size]

    @staticmethod
    def remove_top_clusters(clusters:List, topk:int):
        sort_idx = np.argsort([len(c) for c in clusters])[-topk-1::-1]
        return [clusters[i] for i in sort_idx]

# %% [markdown]
# ## Load data

# %%
data_dir = "/Users/suchith720/Projects/data/beir/msmarco/XC/substring/"

trn_file = f"{data_dir}/substring_trn_X_Y.npz"
tst_file = f"{data_dir}/substring_tst_X_Y.npz"
info_file = f"{data_dir}/raw_data/substring.raw.csv"

trn_meta, tst_meta = sp.load_npz(trn_file), sp.load_npz(tst_file)
meta_info = pd.read_csv(info_file)

meta_phrases = sp.load_npz(f"{data_dir}/derived-phrases_substring_X_Y.npz")

# %%
model_dir = "/Users/suchith720/Downloads/00_msmarco-gpt-concept-substring-linker-with-ngame-loss-001/"

# %%
with pd.option_context("display.max_colwidth", None):
    display(meta_info.head())
# Out:
#    identifier                                                 text
# 0           0                     success of the Manhattan Project
# 1           1  hundreds of thousands of innocent lives obliterated
# 2           2                                  Restorative justice
# 3           3                                                amber
# 4           4                                     shades of yellow

# %% [markdown]
# ## `Semantic:` Connected components

# %%
meta_mat = sp.load_npz(f"{model_dir}/test_predictions_labels.npz")

# %%
meta_mat = sp.load_npz(f"{model_dir}/test_predictions_labels_msmarco-distilbert-cos-v5.npz")

# %%
print(json.dumps(display_similar_items(meta_mat, n_data=10, n_view_data=20, seed=1000), indent=4))
# Out:
# [
#     {
#         "Substring": "fascial aches, pains, tension and restrictions",
#         "Predictions": [
#             [
#                 "fascial aches, pains, tension and restrictions",
#                 1.0
#             ],
#             [
#                 "Muscle pain and aches",
#                 0.6356141567230225
#             ],
#             [
#                 "muscle aches and pain",
#                 0.6307234168052673
#             ],
#             [
#                 "pain and muscle tension",
#                 0.6281501650810242
#             ],
#             [
#                 "Muscle Aches and Pains",
#                 0.6267786622047424
#             ],
#             [
#                 "muscle aches and pains",
#                 0.6267786622047424
#             ],
#             [
#                 "Muscle aches and pains",
#                 0.6267786622047424
#             ],
#             [
#                 "muscle aches and soreness",
#                 0.6230722665786743
#             ],
#             [
#                 "Aches, pains, and tense muscles",
#                 0.6203035712242126
#             ],
#             [
#                 "Muscle aches or stiffness",
#                 0.6148664355278015
#             ]
#         ]
#     },
#     {
#         "Substring": "various branches of engineering",
#         "Predictions": [
#             [
#                 "various branches of engineering",
#                 1.0
#             ],
#             [
#                 "branch of engineering",
#                 0.885352611541748
#             ],
#             [
#                 "branch of engineering science",
#                 0.8351829648017883
#             ],
#             [
#                 "branch of civil engineering",
#                 0.7682232856750488
#             ],
#             [
#                 "branch of mechanical engineering",
#                 0.7445540428161621
#             ],
#             [
#                 "various disciplines of engineering",
#                 0.7442011833190918
#             ],
#             [
#                 "various disciplines in engineering",
#                 0.7241650819778442
#             ],
#             [
#                 "one of the oldest branches of engineering",
#                 0.7184213399887085
#             ],
#             [
#                 "branches of science",
#                 0.7069303393363953
#             ],
#             [
#                 "related field of engineering",
#                 0.6998162269592285
#             ]
#         ]
#     },
#     {
#         "Substring": "average number of moves is 40.04",
#         "Predictions": [
#             [
#                 "average number of moves is 40.04",
#                 1.0
#             ],
#             [
#                 "roughly 40 moves",
#                 0.7621929049491882
#             ],
#             [
#                 "45 moves or fewer",
#                 0.7153153419494629
#             ],
#             [
#                 "20 moves or less",
#                 0.695374608039856
#             ],
#             [
#                 "50 moves",
#                 0.6934675574302673
#             ],
#             [
#                 "50 moves of pieces",
#                 0.6205414533615112
#             ],
#             [
#                 "Moving Average",
#                 0.5769718885421753
#             ],
#             [
#                 "moving average",
#                 0.5769718885421753
#             ],
#             [
#                 "moves you 3.6 km",
#                 0.5435222387313843
#             ],
#             [
#                 "moves around",
#                 0.5253832340240479
#             ]
#         ]
#     },
#     {
#         "Substring": "another four minutes",
#         "Predictions": [
#             [
#                 "another four minutes",
#                 1.0000001192092896
#             ],
#             [
#                 "another 3 minutes",
#                 0.9751718640327454
#             ],
#             [
#                 "another 10 minutes",
#                 0.9741383194923401
#             ],
#             [
#                 "another 15 minutes",
#                 0.9727894067764282
#             ],
#             [
#                 "another 30 minutes",
#                 0.9615613222122192
#             ],
#             [
#                 "another 45 minutes",
#                 0.9582081437110901
#             ],
#             [
#                 "another five minutes or so",
#                 0.9511233568191528
#             ],
#             [
#                 "another 5-8 minutes",
#                 0.948582649230957
#             ],
#             [
#                 "another 3-5 minutes",
#                 0.9479246735572815
#             ],
#             [
#                 "another six to eight minutes",
#                 0.9443985223770142
#             ]
#         ]
#     },
#     {
#         "Substring": "alleged supernatural agency",
#         "Predictions": [
#             [
#                 "alleged supernatural agency",
#                 1.0
#             ],
#             [
#                 "performed by or involving a supernatural power or agency",
#                 0.6593413352966309
#             ],
#             [
#                 "agency of evil spirits",
#                 0.621350884437561
#             ],
#             [
#                 "supernatural forces",
#                 0.5815116763114929
#             ],
#             [
#                 "supernatural beings",
#                 0.5788688063621521
#             ],
#             [
#                 "supernatural force",
#                 0.5765345096588135
#             ],
#             [
#                 "quasi-governmental agency",
#                 0.5609553456306458
#             ],
#             [
#                 "supernatural being",
#                 0.5607917904853821
#             ],
#             [
#                 "licensed detective agency",
#                 0.5581475496292114
#             ],
#             [
#                 "alleged psychic ability",
#                 0.556546151638031
#             ]
#         ]
#     },
#     {
#         "Substring": "Store peaches in a refrigerator",
#         "Predictions": [
#             [
#                 "Store peaches in a refrigerator",
#                 1.0
#             ],
#             [
#                 "Store ripe plums in the refrigerator",
#                 0.6441871523857117
#             ],
#             [
#                 "store them in the refrigerator",
#                 0.6289747953414917
#             ],
#             [
#                 "Store live oysters in the refrigerator",
#                 0.6277080774307251
#             ],
#             [
#                 "canned peaches",
#                 0.6238091588020325
#             ],
#             [
#                 "store it in the refrigerator",
#                 0.6197673082351685
#             ],
#             [
#                 "store in the refrigerator",
#                 0.6089034080505371
#             ],
#             [
#                 "Store in the refrigerator",
#                 0.6089034080505371
#             ],
#             [
#                 "store them in the fridge",
#                 0.6079322695732117
#             ],
#             [
#                 "Store in the refrigerator or freezer",
#                 0.5943941473960876
#             ]
#         ]
#     },
#     {
#         "Substring": "break through the gum",
#         "Predictions": [
#             [
#                 "break through the gum",
#                 1.0
#             ],
#             [
#                 "break free from gum wall",
#                 0.8032627105712891
#             ],
#             [
#                 "through the gums",
#                 0.7440656423568726
#             ],
#             [
#                 "tooth cuts through the gums",
#                 0.7116954326629639
#             ],
#             [
#                 "broken off at the gum line",
#                 0.6972758173942566
#             ],
#             [
#                 "blocked as it is pushing through the gum",
#                 0.6553546190261841
#             ],
#             [
#                 "pull the clot from the hole in your gum",
#                 0.6385735273361206
#             ],
#             [
#                 "including from your gums",
#                 0.6309804320335388
#             ],
#             [
#                 "open up the gum tissue",
#                 0.6218334436416626
#             ],
#             [
#                 "crack or break your teeth",
#                 0.6204879283905029
#             ]
#         ]
#     },
#     {
#         "Substring": "mob is short for mobile",
#         "Predictions": [
#             [
#                 "mob is short for mobile",
#                 1.0
#             ],
#             [
#                 "term mob is short for mobile",
#                 0.9417310953140259
#             ],
#             [
#                 "Mobic",
#                 0.6080522537231445
#             ],
#             [
#                 "the Mob",
#                 0.6070733070373535
#             ],
#             [
#                 "mobd",
#                 0.6057234406471252
#             ],
#             [
#                 "MOBA",
#                 0.603011965751648
#             ],
#             [
#                 "derived from mob and the suffix -ster",
#                 0.5725458860397339
#             ],
#             [
#                 "Mobtracer.in",
#                 0.5619997978210449
#             ],
#             [
#                 "MobyMax",
#                 0.5439125299453735
#             ],
#             [
#                 "brand name Mobic",
#                 0.5438929796218872
#             ]
#         ]
#     },
#     {
#         "Substring": "observed in all Canadian provinces",
#         "Predictions": [
#             [
#                 "observed in all Canadian provinces",
#                 1.0000001192092896
#             ],
#             [
#                 "most Canadian provinces",
#                 0.6900883913040161
#             ],
#             [
#                 "some provinces in Canada",
#                 0.6883959770202637
#             ],
#             [
#                 "all of the Canadian Provinces",
#                 0.6752592921257019
#             ],
#             [
#                 "10 Canadian provinces",
#                 0.6551899313926697
#             ],
#             [
#                 "In Canada",
#                 0.6445889472961426
#             ],
#             [
#                 "in Canada",
#                 0.6445889472961426
#             ],
#             [
#                 "within Canada",
#                 0.637825608253479
#             ],
#             [
#                 "specific Canadian provinces",
#                 0.6349632740020752
#             ],
#             [
#                 "across Canada",
#                 0.6282203197479248
#             ]
#         ]
#     },
#     {
#         "Substring": "vast difference between them",
#         "Predictions": [
#             [
#                 "vast difference between them",
#                 1.0
#             ],
#             [
#                 "vast difference",
#                 0.8082575798034668
#             ],
#             [
#                 "main difference between them",
#                 0.7715533971786499
#             ],
#             [
#                 "difference between the two",
#                 0.7031658887863159
#             ],
#             [
#                 "no difference between the two",
#                 0.6866748929023743
#             ],
#             [
#                 "significant differences between them",
#                 0.6828434467315674
#             ],
#             [
#                 "main difference",
#                 0.6659235954284668
#             ],
#             [
#                 "differences between the two",
#                 0.6652809381484985
#             ],
#             [
#                 "only difference",
#                 0.6561926603317261
#             ],
#             [
#                 "there is a difference",
#                 0.6546033024787903
#             ]
#         ]
#     }
# ]

# %%
def from_similarity(lbl_lbl:sp.csr_matrix, score_thresh:Optional[float]=0.3, diff_thresh:Optional[float]=0.2, 
                    sim_topk:Optional[int]=20):
    lbl_lbl = retain_topk(lbl_lbl, k=sim_topk)
    lbl_lbl = Operations.min_clamp(lbl_lbl, score_thresh)
    lbl_lbl = Operations.diff_threshold(lbl_lbl, diff_thresh)
    
    n, groups = sp.csgraph.connected_components(lbl_lbl)
    return Operations.get_clusters(groups)

# %%
clusters = from_similarity(meta_mat, score_thresh=0.5, diff_thresh=0.2, sim_topk=10)

# %%
texts = get_conflated_text(clusters, meta_info)

# %%
print(f"Number of clusters: {len(clusters)}")
# Out:
# Number of clusters: 987959

# %%
texts[10]
# Out:
# ['typical lease',
#  'lease agreement',
#  'Rental Agreements',
#  'parties to the agreement',
#  'terms, conditions, and specifications of the job contract',
#  'binding decision',
#  'binding agreement',
#  'existence of a contractual relationship',
#  'legally binding',
#  'binding contract in the foreign exchange market',
#  'contracts',
#  'Lease/Option',
#  'Lease or Rent with the Option to Buy',
#  'written contract',
#  'agreement creating obligations enforceable by law',
#  'term of a contract',
#  'lease',
#  'terms of an agreement',
#  'legally binding arrangements',
#  'term of the contract',
#  'agreement among the States',
#  'in agreement with the terms in the contract',
#  'written legal contract',
#  'lease agreements',
#  'binding ruling',
#  'deal',
#  'contract',
#  'in order to be legally binding',
#  'as specified in the contract',
#  'employment agreement',
#  'contract between employer and employee',
#  'three-party agreement',
#  'legally binding agreement',
#  'between an employer and an employee',
#  'lease with an option to buy',
#  'agreement made by two parties',
#  'contracts, and other sponsored agreements',
#  'most common contract type',
#  'agreement between two or more persons',
#  'legally enforceable contract',
#  'A legal agreement, contract, or document',
#  'part of a binding agreement',
#  'agreement between two distinct business entities',
#  'legally binding and enforceable contract',
#  'agreement between two parties',
#  'examples of these types of contracts',
#  'understanding between the employer & employee',
#  'type of contract',
#  'employment contract',
#  'works under contract for an employer',
#  'written agreement between the parties',
#  'agreement between an employer and an employee',
#  'terms of the contract',
#  'binding contract',
#  'deal (in)',
#  'signing a legally binding contract',
#  'agreement between certain things',
#  'agreed contract',
#  'contracts between two companies',
#  'agreement between two or more entities',
#  'contracts to do work for another person',
#  'contracts with an employer to do a particular piece of work',
#  'legally enforceable agreement',
#  'legally binding contract',
#  'different types of employment contract',
#  'a lease exists',
#  'perform the terms of the contract',
#  'legally binding document',
#  'contract or legal document',
#  'lease is a contract to rent an asset',
#  'contractual terms',
#  'terms of a contract',
#  'signed contract',
#  'binding legal document',
#  'formal contract',
#  'a court will enforce',
#  'enforceable in a court of law',
#  'legally enforceable contract requires',
#  'agreement between two or more parties',
#  'part of the legally binding agreement',
#  'contract between two or more parties',
#  'agreement between parties',
#  'signed the contract tender',
#  'law, contract, constitution, or other legal document',
#  'how it contracts',
#  'A pact or binding agreement between two or more parties',
#  'legal contract between two or more parties',
#  'enforceable by the courts',
#  'fulfilling the terms of a contract',
#  'sign a written agreement',
#  'Formal contracts',
#  'Types of formal contracts',
#  'such a contract',
#  'contract worker',
#  'a contract',
#  'agreement enforceable by law',
#  'written form of such an agreement',
#  'contract between two parties',
#  'sign a contract',
#  'Rental Agreement (lease)',
#  'formal agreement between two or more parties',
#  'contract terms and labor conditions',
#  'Contract conditions',
#  'binding between the parties',
#  'legal contract',
#  'agreement between two or more states',
#  'all contract obligations will be fulfilled',
#  'contractual arrangement',
#  'Contract positions',
#  'agreement between two or more people',
#  'terms of the deal',
#  'works for a person under a contract',
#  'signed a contract with an agent',
#  'binding agreement or compact',
#  'residential leases',
#  'agreed upon in a contract',
#  'a contract by which one party',
#  'written agreement',
#  'agreement between two parties is made in writing',
#  'legally enforceable and binding agreement',
#  'purpose of a contract',
#  'enforceable contract',
#  'employee who works under contract',
#  'agreement',
#  'legal document summarizing the agreement between parties',
#  'contractual relationship',
#  'binding agreement between two or more persons',
#  'enforceable by law',
#  'specifies the terms of the deal',
#  'agreement made between two or more countries',
#  'A lease or rental agreement is a contract',
#  'contract or agreement between two or more parties',
#  'written agreement signed by the author',
#  'residential lease agreements',
#  'legal agreement between two parties',
#  'agreement to be made',
#  'document that contains the agreement',
#  'agreement in writing',
#  'legally enforceable',
#  'agreement between you and your employer',
#  'contract of employment',
#  'binding agreement between the parties',
#  'contracts with an employer',
#  'one party to the contract is bound',
#  'agreement entered into by two or more parties',
#  'legally-binding contracts',
#  'terms specified in a contract',
#  'agreement between three parties',
#  'signing a contract',
#  'in a written contract',
#  'legal document describing the agreement',
#  'terms of your employment contract',
#  'sign contracts',
#  'between an employer and employee',
#  'term or duration of such a contract',
#  'individuals or party(s) to the contract',
#  'agreement that is not in writing',
#  'enforceable in litigation',
#  'one party to a contract',
#  'written or expressed agreement between two parties',
#  'a binding agreement between two or more persons',
#  'agreements between the employer and employee',
#  'written agreement between the employee and employer',
#  'Lease-Purchase Contract',
#  'Lease Purchase Agreement',
#  'Lease with Option to Purchase Contract',
#  'basic meaning is an agreement',
#  'Conditions of Contract',
#  'make a legally binding contract',
#  'lease is a contractual arrangement',
#  'contractual agreement',
#  'agreement between two companies',
#  'contract between the employer and the key employee',
#  'rental agreement',
#  'contracts and other agreements',
#  'an employment contract',
#  'agreement between the employee and employer',
#  'make them contract',
#  'signed the contract',
#  'leases and rental agreements',
#  'agreement between two enterprises',
#  'leasing options',
#  'signing of a contract',
#  'terms of the contract only become binding when the party offered the contract signs it',
#  'an agreement between states covering particular matters',
#  'A contract is a legal document',
#  'to make a contract',
#  'deals in',
#  'lease a facility',
#  'written, dated and signed agreement',
#  'employment contracts',
#  'terms of the agreement are in writing',
#  'in a contract both parties had agreed upon',
#  'signing contract',
#  'California Residential Lease Agreement',
#  'contract employee',
#  'terms of the contract are fulfilled',
#  'specify in the terms of an agreement',
#  'specify in the terms of a contract',
#  'legal contract between two parties',
#  'an agreement',
#  'binding on the parties',
#  'arrangement, agreement, or contract',
#  'contracts have been written',
#  'identified by the parties to the contract',
#  'formal agreement',
#  'lease is considered a legal contract',
#  'lease interest',
#  'written agreement between parties',
#  'contract between parties',
#  'agreements among states or between nations',
#  'agreement between two people or groups',
#  'signed written agreement',
#  'agreement with an employer',
#  'agreement between members',
#  'contractual relationship between an employee and an employer',
#  'writing or document containing such an agreement',
#  'agreement made between two contracting parties',
#  'contracts are only binding on the parties signing the contract',
#  'legal term for a contract',
#  'legally binding or valid agreement',
#  'legal and binding contract',
#  'existence of a contract',
#  'enforced by the courts',
#  'lease option',
#  'lease purchase',
#  'make an agreement',
#  'contracts and agreements',
#  'agreement that has not been reduced to writing',
#  'agreement between an employer and employee',
#  'written agreement between the parties to a dispute',
#  'each of the parties to the contract',
#  'job contract',
#  'individual signing the contract',
#  'decision is binding on the parties']

# %% [markdown]
# ## `Predictions`

# %%
model_dir = "/Users/suchith720/Downloads/00_msmarco-gpt-concept-substring-linker-with-ngame-loss-001/"
data_meta = sp.load_npz(f"{model_dir}/train_predictions.npz")

# %%
def from_predictions(data_lbl:sp.csr_matrix, score_thresh:Optional[float]=0.3, diff_thresh:Optional[float]=0.2, 
                     pred_topk:Optional[int]=3):
    data_lbl = retain_topk(data_lbl, k=pred_topk)
    data_lbl = Operations.min_clamp(data_lbl, score_thresh)
    data_lbl = Operations.diff_threshold(data_lbl, diff_thresh)
    
    lbl_mat = Operations.compute_yty(data_lbl.transpose())
    n, groups = sp.csgraph.connected_components(lbl_mat)
    return Operations.get_clusters(groups)

# %% [markdown]
# ## `Derived phrases`

# %%
def from_derived_phrases(lbl_phrases:sp.csr_matrix):
    lbl_mat = Operations.compute_yty(lbl_phrases)
    n, groups = sp.csgraph.connected_components(lbl_mat)
    return Operations.get_clusters(groups)

# %%
clusters = from_derived_phrases(meta_phrases)
# Out:
#   0%|          | 0/1658 [00:00<?, ?it/s]

# %%
texts = get_conflated_text(clusters, meta_info)

# %%
len(texts)
# Out:
# 1365625

# %% [markdown]
# ## `Conflation`

# %%
#| export
class Conflate:

    @staticmethod
    def from_similarity(lbl_lbl:sp.csr_matrix, score_thresh:Optional[float]=0.3, diff_thresh:Optional[float]=0.2, 
                        sim_topk:Optional[int]=20):
        lbl_lbl = retain_topk(lbl_lbl, k=sim_topk)
        lbl_lbl = Operations.min_clamp(lbl_lbl, score_thresh)
        lbl_lbl = Operations.diff_threshold(lbl_lbl, diff_thresh)
        
        n, groups = sp.csgraph.connected_components(lbl_lbl)
        return Operations.get_clusters(groups)

    @staticmethod
    def from_predictions(data_lbl:sp.csr_matrix, score_thresh:Optional[float]=0.3, diff_thresh:Optional[float]=0.2, 
                         pred_topk:Optional[int]=3):
        data_lbl = retain_topk(data_lbl, k=pred_topk)
        data_lbl = Operations.min_clamp(data_lbl, score_thresh)
        data_lbl = Operations.diff_threshold(data_lbl, diff_thresh)
        
        lbl_mat = Operations.compute_yty(data_lbl.transpose())
        n, groups = sp.csgraph.connected_components(lbl_mat)
        return Operations.get_clusters(groups)

    @staticmethod
    def from_derived_phrases(lbl_phrases:sp.csr_matrix):
        lbl_mat = Operations.compute_yty(lbl_phrases)
        n, groups = sp.csgraph.connected_components(lbl_mat)
        return Operations.get_clusters(groups)

# %% [markdown]
# ## `Save data`

# %%
#| export
class SaveData:

    @staticmethod
    def get_groups(clusters:List, n_lbl:int):
        groups = np.full(n_lbl, -1)
        for i,idx in enumerate(clusters):
            groups[idx] = i
        idxs = np.where(groups == -1)[0]
        groups[idxs] = np.arange(len(clusters), len(clusters) + idxs.shape[0])
        return groups

    @staticmethod
    def conflate_matrix(matrix:sp.csr_matrix, groups:np.array, n_lbl:Optional[int]=None):
        data, indptr = matrix.data, matrix.indptr
        indices = [groups[i] for i in matrix.indices]
        shape = None if n_lbl is None else (matrix.shape[0], n_lbl)
        return sp.csr_matrix((data, indices, indptr), shape=shape)

    @staticmethod
    def get_conflated_info(clusters:List, info:Dict):
        conflated_info, flag = dict(), np.zeros(len(info["identifier"]))
        for idxs in clusters:
            idx = np.random.choice(idxs)
            conflated_info.setdefault("identifier", []).append(info["identifier"][idx])
            conflated_info.setdefault("text", []).append(info["text"][idx])
            flag[idxs] = 1
        idxs = np.where(flag == 0)[0]
        for idx in idxs:
            conflated_info.setdefault("identifier", []).append(info["identifier"][idx])
            conflated_info.setdefault("text", []).append(info["text"][idx])
            flag[idx] = 1
        assert flag.all(), "All items should be covered."
        return conflated_info

    @staticmethod
    def save_raw(fname:str, ids:List, txt:List):
        df = pd.DataFrame({"identifier": ids, "text": txt})
        df.to_csv(fname, index=False)

    @staticmethod
    def proc(save_dir:str, trn_lbl:sp.csr_matrix, lbl_info:Dict, clusters:List, tst_lbl:Optional[sp.csr_matrix]=None):
        groups = get_groups(clusters, n_lbl=trn_meta.shape[1])

        conflated_trn_meta = conflate_matrix(trn_meta, groups)
        conflated_tst_meta = conflate_matrix(tst_meta, groups, n_lbl=conflated_trn_meta.shape[1])
        conflated_meta_info = get_conflated_info(clusters, meta_info)

        n = len([o for o in os.listdir(save_dir) if re.match(r'conflation_[0-9]{2}', o)]) + 1
        save_dir = f"{save_dir}/conflation_{n:02d}"
        
        raw_dir = f"{save_dir}/raw_data"
        os.makedirs(raw_dir, exist_ok=True)

        sp.save_npz(f"{save_dir}/{os.path.basename(trn_file)}", conflated_trn_meta)
        sp.save_npz(f"{save_dir}/{os.path.basename(tst_file)}", conflated_tst_meta)

        raw_file = f"{raw_dir}/{os.path.basename(info_file)}"
        save_raw(raw_file, conflated_meta_info["identifier"], conflated_meta_info["text"])
