# %% [markdown]
# # `Conflation`

# %%
#| default_exp conflate

# %%
#| export
import numpy as np, pandas as pd, scipy.sparse as sp, torch, json, os, re
import matplotlib.pyplot as plt
from IPython.display import display

from tqdm.auto import tqdm
from typing import Optional, Union, Dict, List
from IPython.display import display
from xclib.utils.sparse import retain_topk
from collections import Counter

# %% [markdown]
# ## Helper functions

# %%
#| export
def display_items(matrix:sp.csr_matrix, info:Dict, n_data:Optional[int]=10, n_view_data:Optional[int]=20, 
                          seed:Optional[int]=1000):
    np.random.seed(seed)
    rnd_idx = np.random.permutation(matrix.shape[0])[:n_data]
    
    outputs = list()
    for idx in rnd_idx:
        sort_idx = np.argsort(matrix[idx].data)[:-n_view_data:-1]
        scores = matrix[idx].data[sort_idx]
        indices = matrix[idx].indices[sort_idx]
        labels = [info['text'][i] for i in indices]
        o = {
            "Substring": info['text'][idx],
            "Predictions": [(x, float(y)) for x,y in zip(labels, scores)]
        }
        outputs.append(o)
    return outputs

# %%
#| export
def compare_items(output_1, output_2):
    rows, index = [], []
    for x,y in zip(linker_output, pretrn_output):
        assert x["Substring"] == y["Substring"]
    
        index.extend([(x["Substring"], i+1) for i in range(len(x["Predictions"]))])
        rows.extend([(a[0], b[0]) for a,b in zip(x["Predictions"], y["Predictions"])])
        
    df = pd.DataFrame(
        rows,
        index=pd.MultiIndex.from_tuples(
            index,
            names=["Query", "Index"],
        ),
        columns=["Output 1", "Output 2"],
    )
    return df

# %%
#| export
def get_conflated_text(clusters:List, meta_info:Dict):
    texts = [[meta_info["text"][i] for i in c] for c in clusters]
    idx = np.argsort([len(c) for c in clusters])[::-1]
    return [texts[i] for i in idx]

# %%
#| export
class Operations:

    @staticmethod
    def compute_yty(mat:sp.csr_matrix, bsz:Optional[int]=1000, normalize=True):
        mat_t = mat.transpose()
        out = sp.vstack([mat[i:i+bsz]@mat_t for i in tqdm(range(0, mat.shape[0], bsz))])
        def invert(a):
            return np.divide(1.0, a, out=np.zeros_like(a), where=a!=0)
        return out.multiply(invert(out.sum(axis=1))).multiply(invert(out.sum(axis=0))).tocsr()

    @staticmethod
    def minimum(matrix:sp.csr_matrix):
        return np.array([matrix.data[i:j].min() for i,j in zip(matrix.indptr, matrix.indptr[1:])])

    @staticmethod
    def min_clamp(matrix:sp.csr_matrix, value:float, inplace:Optional[bool]=True):
        if not inplace:
            matrix = matrix.copy()
        matrix.data[matrix.data <= value] = 0
        matrix.eliminate_zeros()
        return matrix

    @staticmethod
    def max_clamp(matrix:sp.csr_matrix, value:float, inplace:Optional[bool]=True):
        if not inplace:
            matrix = matrix.copy()
        matrix.data[matrix.data >= value] = 0
        matrix.eliminate_zeros()
        return matrix

    @staticmethod
    def diff_threshold(matrix:sp.csr_matrix, value:float):
        for i,j in zip(matrix.indptr, matrix.indptr[1:]):
            data = matrix.data[i:j]
            if len(data):
                idx = np.where(data.max() - data > value)[0]
                data[idx] = 0.0
                matrix.data[i:j] = data
        matrix.eliminate_zeros()
        return matrix

    @staticmethod
    def get_clusters(groups:np.array, lbl_idx:Optional[np.array]=None):
        lbl_idx = np.arange(groups.shape[0]) if lbl_idx is None else lbl_idx
        assert groups.shape == lbl_idx.shape, "`groups` and `lbl_idx` must have the same shape."
        clusters = dict()
        for k,v in zip(groups, lbl_idx): 
            clusters.setdefault(k, []).append(v)
        clusters = list(clusters.values())
        
        cluster_sz = [len(c) for c in clusters]
        sort_idx = np.argsort(cluster_sz)[::-1]
        return [clusters[i] for i in sort_idx]

# %%
#| export
class Filter:

    @staticmethod
    def from_max_size(clusters:List, size:int):
        return [c for c in clusters if len(c) < size]

    @staticmethod
    def from_min_size(clusters:List, size:int):
        return [c for c in clusters if len(c) > size]

    @staticmethod
    def remove_top_clusters(clusters:List, topk:int):
        sort_idx = np.argsort([len(c) for c in clusters])[-topk-1::-1]
        return [clusters[i] for i in sort_idx]

# %% [markdown]
# ## Load data

# %%
data_dir = "/Users/suchith720/Projects/data/beir/msmarco/XC/substring/"

trn_file = f"{data_dir}/substring_trn_X_Y.npz"
tst_file = f"{data_dir}/substring_tst_X_Y.npz"
info_file = f"{data_dir}/raw_data/substring.raw.csv"

trn_meta, tst_meta = sp.load_npz(trn_file), sp.load_npz(tst_file)
meta_info = pd.read_csv(info_file)

meta_phrases = sp.load_npz(f"{data_dir}/derived-phrases_substring_X_Y.npz")

# %%
linker_dir = "/Users/suchith720/Downloads/00_msmarco-gpt-concept-substring-linker-with-ngame-loss-001/"

# %%
with pd.option_context("display.max_colwidth", None):
    display(meta_info.head())
# Out:
#    identifier                                                 text
# 0           0                     success of the Manhattan Project
# 1           1  hundreds of thousands of innocent lives obliterated
# 2           2                                  Restorative justice
# 3           3                                                amber
# 4           4                                     shades of yellow

# %% [markdown]
# ## Clustering

# %% [markdown]
# ### `Semantic:` Connected components

# %%
lnk_meta_mat = retain_topk(sp.load_npz(f"{linker_dir}/test_predictions_labels.npz"), k=10)
ptr_meta_mat = retain_topk(sp.load_npz(f"{linker_dir}/test_predictions_labels_msmarco-distilbert-cos-v5.npz"), k=10)

# %%
lnk_meta_mat.shape, ptr_meta_mat.shape
# Out:
# ((1657190, 1657190), (1657190, 1657190))

# %%
linker_output = display_similar_items(lnk_meta_mat, meta_info, n_data=10, n_view_data=20, seed=1000)
pretrn_output = display_similar_items(ptr_meta_mat, meta_info, n_data=10, n_view_data=20, seed=1000)

# %%
df = compare_items(linker_output, pretrn_output)

# %%
with pd.option_context('display.max_rows', None):
    display(df)
# Out:
#                                                                                                Output 1  \
# Query                                          Index
# fascial aches, pains, tension and restrictions 1                                       investing fascia
#                                                2                                        spasm-type pain
#                                                3         fascial aches, pains, tension and restrictions
#                                                4                                 restrictions in fascia
#                                                5                      osteoarthritis-related joint pain
#                                                6                   Relieving pain of normal intact skin
#                                                7                            muscles, ligaments, tendons
#                                                8                                      contours the body
#                                                9                              deeper and thicker fascia
#                                                10        penetrates deep into aching muscles and joints
# various branches of engineering                1       highly specialized professional technical degree
#                                                2      study of the theory, experimentation, and engi...
#                                                3      conceive, design, build, supervise, operate, c...
#                                                4      engineer who is registered with the Engineerin...
#                                                5                                  branch of engineering
#                                                6                                        Civil engineers
#                                                7      oldest, broadest and largest of all other engi...
#                                                8      application of science and engineering principles
#                                                9      develop ways to utilize economically the mater...
#                                                10           Principles and Practice of Engineering (PE)
# average number of moves is 40.04               1                           target number to roll is a 1
#                                                2                                               50 moves
#                                                3                                     magic number at 60
#                                                4                           500 meters on a point target
#                                                5                                  price action analysis
#                                                6                  how many units they are likely to buy
#                                                7                       average litter size is 3 puppies
#                                                8                                       20 moves or less
#                                                9                                               1 Putter
#                                                10                                more liquid the market
# another four minutes                           1                             cook for another 2 minutes
#                                                2                                       sear the outside
#                                                3                                  take up to 30 minutes
#                                                4            Let stand, still covered, another 3 minutes
#                                                5                        grill until you get a good sear
#                                                6                                 2 minutes on each side
#                                                7                                           flip it over
#                                                8                                    1 to 2 minutes each
#                                                9                                        pollock fillets
#                                                10                              additional 4 - 6 minutes
# alleged supernatural agency                    1                                   illusion or delusion
#                                                2                                     supernatural being
#                                                3                                    opposite of falsism
#                                                4                         supernatural spiritual ecstasy
#                                                5                                             nigromancy
#                                                6                spiritual principle of cause and effect
#                                                7                              evil and selfish purposes
#                                                8                    causes good or bad things to happen
#                                                9                              divine self-manifestation
#                                                10                        foreshadowing evil or disaster
# Store peaches in a refrigerator                1      Unripe berries are bitter while ripe ones are ...
#                                                2               Cling, cling-free and semi-cling peaches
#                                                3                       avoid jerking it off of the tree
#                                                4                                   wrap in freezer wrap
#                                                5                              Peach twigs can be killed
#                                                6                         a few days at room temperature
#                                                7               a touch of sugar to bring out the juices
#                                                8                         remove all fruit from the tree
#                                                9                                 heavy-duty freezer bag
#                                                10                                     Avoid overheating
# break through the gum                          1                              Tartar above the gum line
#                                                2                               massage around your gums
#                                                3                                             lower gums
#                                                4                                destruction of the gums
#                                                5                                     Thinner gum tissue
#                                                6                     something caught between his teeth
#                                                7                                very severe gum disease
#                                                8                                       Dry, sticky gums
#                                                9                                         infected tooth
#                                                10                     soreness and swelling of the gums
# mob is short for mobile                        1                  MOBO Awards for Music of Black Origin
#                                                2       Android devices come with a simple shell program
#                                                3            /give (player name) minecraft:command_block
#                                                4                                 Mobipocket file format
#                                                5                            some ranged combat (bombs!)
#                                                6                                players hide in an area
#                                                7                           leading cell phone directory
#                                                8                                        file type .mobi
#                                                9                         detect this threat as Softonic
#                                                10                           Soldiers in combat vehicles
# observed in all Canadian provinces             1                                  10 Canadian provinces
#                                                2                                         most of Canada
#                                                3                one of the 10 US legal federal holidays
#                                                4                                         parts of Japan
#                                                5                          portions of the United States
#                                                6                                       all 50 US states
#                                                7                     summer months (referred to as EDT)
#                                                8                  each province and territory in Canada
#                                                9                                   different time zones
#                                                10                  much of the contiguous United States
# vast difference between them                   1                                  different personality
#                                                2                                       unique qualities
#                                                3                                      reads differently
#                                                4                            human behavior is shaped by
#                                                5                rarely communicate accurate information
#                                                6                                        learned from it
#                                                7                                         personal level
#                                                8                      The only difference is their diet
#                                                9                               requires more brain work
#                                                10                similarities between those same people
#
#                                                                                                Output 2
# Query                                          Index
# fascial aches, pains, tension and restrictions 1         fascial aches, pains, tension and restrictions
#                                                2                                  Muscle pain and aches
#                                                3                                  muscle aches and pain
#                                                4                                pain and muscle tension
#                                                5                                 Muscle Aches and Pains
#                                                6                                 muscle aches and pains
#                                                7                                 Muscle aches and pains
#                                                8                              muscle aches and soreness
#                                                9                        Aches, pains, and tense muscles
#                                                10                             Muscle aches or stiffness
# various branches of engineering                1                        various branches of engineering
#                                                2                                  branch of engineering
#                                                3                          branch of engineering science
#                                                4                            branch of civil engineering
#                                                5                       branch of mechanical engineering
#                                                6                     various disciplines of engineering
#                                                7                     various disciplines in engineering
#                                                8              one of the oldest branches of engineering
#                                                9                                    branches of science
#                                                10                          related field of engineering
# average number of moves is 40.04               1                       average number of moves is 40.04
#                                                2                                       roughly 40 moves
#                                                3                                      45 moves or fewer
#                                                4                                       20 moves or less
#                                                5                                               50 moves
#                                                6                                     50 moves of pieces
#                                                7                                         Moving Average
#                                                8                                         moving average
#                                                9                                       moves you 3.6 km
#                                                10                                          moves around
# another four minutes                           1                                   another four minutes
#                                                2                                      another 3 minutes
#                                                3                                     another 10 minutes
#                                                4                                     another 15 minutes
#                                                5                                     another 30 minutes
#                                                6                                     another 45 minutes
#                                                7                             another five minutes or so
#                                                8                                    another 5-8 minutes
#                                                9                                    another 3-5 minutes
#                                                10                          another six to eight minutes
# alleged supernatural agency                    1                            alleged supernatural agency
#                                                2      performed by or involving a supernatural power...
#                                                3                                 agency of evil spirits
#                                                4                                    supernatural forces
#                                                5                                    supernatural beings
#                                                6                                     supernatural force
#                                                7                              quasi-governmental agency
#                                                8                                     supernatural being
#                                                9                              licensed detective agency
#                                                10                               alleged psychic ability
# Store peaches in a refrigerator                1                        Store peaches in a refrigerator
#                                                2                   Store ripe plums in the refrigerator
#                                                3                         store them in the refrigerator
#                                                4                 Store live oysters in the refrigerator
#                                                5                                         canned peaches
#                                                6                           store it in the refrigerator
#                                                7                              store in the refrigerator
#                                                8                              Store in the refrigerator
#                                                9                               store them in the fridge
#                                                10                  Store in the refrigerator or freezer
# break through the gum                          1                                  break through the gum
#                                                2                               break free from gum wall
#                                                3                                       through the gums
#                                                4                            tooth cuts through the gums
#                                                5                             broken off at the gum line
#                                                6               blocked as it is pushing through the gum
#                                                7                pull the clot from the hole in your gum
#                                                8                               including from your gums
#                                                9                                 open up the gum tissue
#                                                10                             crack or break your teeth
# mob is short for mobile                        1                                mob is short for mobile
#                                                2                           term mob is short for mobile
#                                                3                                                  Mobic
#                                                4                                                the Mob
#                                                5                                                   mobd
#                                                6                                                   MOBA
#                                                7                  derived from mob and the suffix -ster
#                                                8                                           Mobtracer.in
#                                                9                                                MobyMax
#                                                10                                      brand name Mobic
# observed in all Canadian provinces             1                     observed in all Canadian provinces
#                                                2                                most Canadian provinces
#                                                3                               some provinces in Canada
#                                                4                          all of the Canadian Provinces
#                                                5                                  10 Canadian provinces
#                                                6                                              In Canada
#                                                7                                              in Canada
#                                                8                                          within Canada
#                                                9                            specific Canadian provinces
#                                                10                                         across Canada
# vast difference between them                   1                           vast difference between them
#                                                2                                        vast difference
#                                                3                           main difference between them
#                                                4                             difference between the two
#                                                5                          no difference between the two
#                                                6                   significant differences between them
#                                                7                                        main difference
#                                                8                            differences between the two
#                                                9                                        only difference
#                                                10                                 there is a difference

# %%
def from_similarity(lbl_lbl:sp.csr_matrix, score_thresh:Optional[float]=0.3, diff_thresh:Optional[float]=0.2, 
                    sim_topk:Optional[int]=20):
    lbl_lbl = retain_topk(lbl_lbl, k=sim_topk)
    lbl_lbl = Operations.min_clamp(lbl_lbl, score_thresh)
    lbl_lbl = Operations.diff_threshold(lbl_lbl, diff_thresh)
    
    n, groups = sp.csgraph.connected_components(lbl_lbl)
    return Operations.get_clusters(groups)

# %%
lnk_clusters = from_similarity(lnk_meta_mat, score_thresh=0.5, diff_thresh=0.2, sim_topk=3)

# %%
ptr_clusters = from_similarity(ptr_meta_mat, score_thresh=0.5, diff_thresh=0.2, sim_topk=10)

# %%
lnk_cluster_text = get_conflated_text(lnk_clusters, meta_info)

# %%
ptr_cluster_text = get_conflated_text(ptr_clusters, meta_info)

# %%
lnk_cluster_text[100]
# Out:
# ['FB may be a Hallmark',
#  'FB stands for Franz Bibus',
#  'BEB',
#  'people can comment just like Facebook',
#  '5$ a day in advertising on Facebook']

# %%
ptr_cluster_text[10000]
# Out:
# ['causing the scabbing',
#  'scab',
#  'scabbing',
#  'Also called scab',
#  'cause scabbing',
#  'a scab']

# %% [markdown]
# ### `Predictions`

# %%
model_dir = "/Users/suchith720/Downloads/00_msmarco-gpt-concept-substring-linker-with-ngame-loss-001/"
data_meta = sp.load_npz(f"{model_dir}/train_predictions.npz")

# %%
def from_predictions(data_lbl:sp.csr_matrix, score_thresh:Optional[float]=0.3, diff_thresh:Optional[float]=0.2, 
                     pred_topk:Optional[int]=3):
    data_lbl = retain_topk(data_lbl, k=pred_topk)
    data_lbl = Operations.min_clamp(data_lbl, score_thresh)
    data_lbl = Operations.diff_threshold(data_lbl, diff_thresh)
    
    lbl_mat = Operations.compute_yty(data_lbl.transpose())
    n, groups = sp.csgraph.connected_components(lbl_mat)
    return Operations.get_clusters(groups)

# %% [markdown]
# ### `Derived phrases`

# %%
def from_derived_phrases(lbl_phrases:sp.csr_matrix):
    lbl_mat = Operations.compute_yty(lbl_phrases)
    n, groups = sp.csgraph.connected_components(lbl_mat)
    return Operations.get_clusters(groups)

# %%
clusters = from_derived_phrases(meta_phrases)
# Out:
#   0%|          | 0/1658 [00:00<?, ?it/s]

# %%
texts = get_conflated_text(clusters, meta_info)

# %%
texts[2]
# Out:
# ['high cholesterol',
#  'cholesterol',
#  'High Levels Of Fat In The Blood',
#  'reduce LDL cholesterol in blood',
#  'High blood cholesterol levels',
#  'High cholesterol',
#  'help you elevate your HDL',
#  'raises HDL',
#  'lower your cholesterol',
#  'your LDL, or bad cholesterol',
#  'improve your cholesterol numbers',
#  'help lower cholesterol',
#  'lower high cholesterol',
#  'dyslipidemia',
#  'lowering cholesterol levels',
#  'increases the good HDL cholesterol',
#  'to lower cholesterol',
#  'LDL (bad) cholesterol',
#  'low-density lipoprotein cholesterol (LDLc)',
#  'lower blood cholesterol',
#  'treat high cholesterol levels',
#  'raise the level of cholesterol in the blood',
#  'lower cholesterol',
#  'reduce your cholesterol',
#  'increased cholesterol levels',
#  'treat high cholesterol',
#  'increase bad cholesterol',
#  'LDL cholesterol',
#  'higher levels of bad cholesterol',
#  'help maintain healthy cholesterol levels',
#  'lower the bad cholesterol levels',
#  'total cholesterol levels',
#  'increased serum cholesterol',
#  'keep a lid on cholesterol',
#  'control cholesterol',
#  'bad cholesterol',
#  'low-density lipoprotein',
#  'reduce LDL or bad cholesterol levels',
#  'cholesterol molecules',
#  'low-density lipoprotein (LDL, or bad) cholesterol',
#  'Lower cholesterol',
#  'LDL ("bad") cholesterol',
#  'low density lipoprotein cholesterol (LDL-C)',
#  'lower LDL (bad) cholesterol levels',
#  'very high cholesterol levels',
#  'lower LDL cholesterol',
#  'treating high cholesterol',
#  'fight off bad cholesterol',
#  'cholesterol-rich',
#  'helps lower bad cholesterol',
#  'improve blood cholesterol levels',
#  'LDL (bad cholesterol)',
#  'raise cholesterol levels',
#  'raising your good cholesterol',
#  'reduce LDL (bad) cholesterol',
#  'relief from high cholesterol',
#  'high-cholesterol foods',
#  'Lower Cholesterol',
#  'reduce your LDL cholesterol levels',
#  'help lower your cholesterol',
#  'reduce overall cholesterol levels',
#  'raise good cholesterol (HDL)',
#  'lowering the bad cholesterol',
#  'reduce the amount of cholesterol in diet',
#  'lowering cholesterol',
#  'levels of cholesterol',
#  'total cholesterol',
#  'low-density lipoprotein (LDL)',
#  'less cholesterol',
#  'improve cholesterol levels',
#  'High blood cholesterol',
#  'high cholesterol levels',
#  'Healthy Cholesterol Level Support',
#  'lower bad cholesterol',
#  'lower the LDL cholesterol',
#  'lowers cholesterol',
#  'bad LDL cholesterol',
#  'dietary cholesterol',
#  'reduce cholesterol',
#  'reduce blood cholesterol levels',
#  'high bad cholesterol',
#  'the bad cholesterol',
#  'used for high cholesterol',
#  'lowering of cholesterol',
#  'cholesterol management',
#  'especially high in cholesterol',
#  'Low-density lipoproteins (LDL)',
#  'High levels of LDL cholesterol',
#  'high level of good HDL',
#  'improves blood cholesterol levels',
#  'Low-density lipoprotein (LDL)',
#  'bad kind of cholesterol',
#  'boost levels of good HDL cholesterol',
#  'high cholesterol in the blood',
#  'lower cholesterol levels',
#  'higher bad cholesterol or LDL',
#  'reduce cholesterol level in blood',
#  'build LDL cholesterol',
#  'increase of LDL cholesterol',
#  'lower blood cholesterol levels',
#  'relief from high cholesterol levels',
#  'Reduces cholesterol',
#  'reduce bad cholesterol',
#  'LDL',
#  'elevate HDL cholesterol',
#  'decrease the amount of cholesterol',
#  'Dyslipidemia',
#  'abnormal amount of lipids',
#  'high levels of fat in the blood',
#  'Total Cholesterol',
#  'lower the level of your "bad" cholesterol (LDL)',
#  'increase the level of your "good" cholesterol (HDL)',
#  'lower the levels of bad cholesterol',
#  'LDL levels',
#  'Lowers Cholesterol',
#  'manages cholesterol levels',
#  'lowering levels of cholesterol',
#  'improve your cholesterol',
#  'lower total cholesterol',
#  'increase good cholesterol',
#  'benefits cholesterol',
#  'high levels of cholesterol',
#  'reduce the amount of cholesterol in the blood',
#  'increase healthy HDL cholesterol levels',
#  'lower LDL cholesterol levels',
#  'Cholesterol screening',
#  'reducing cholesterol',
#  'increase your good cholesterol levels',
#  'high proportion of cholesterol',
#  'LDL bad cholesterol',
#  'elevated cholesterol levels',
#  'rise in blood cholesterol',
#  'Low-density lipoprotein cholesterol',
#  "'bad' cholesterol",
#  'increase the level of LDL cholesterol',
#  'used to treat high cholesterol',
#  'cholesterol particles in the blood',
#  'too much cholesterol',
#  'Hypercholesterolemia',
#  'high levels of cholesterol in the blood',
#  'hyperlipidemia',
#  'elevated levels of lipids in the blood',
#  'lowers the level of cholesterol in the blood',
#  'higher than normal cholesterol levels',
#  'increased the level of HDL cholesterol',
#  'source of cholesterol',
#  'helps decrease cholesterol levels',
#  'increase your HDL level',
#  'boost HDL',
#  'raise HDL cholesterol levels',
#  'lipid disorder',
#  'hypercholesterolemia',
#  'helping lower cholesterol',
#  'Low-density lipoprotein',
#  'reduce LDL cholesterol',
#  'High HDL level',
#  'Lower Cholesterol Level',
#  'raising high-density lipoproteins (HDL)',
#  'good cholesterol level',
#  'reduces LDL (bad Cholesterol)',
#  'increases HDL (good cholesterol)',
#  'increase HDL (good) cholesterol',
#  'reduce high cholesterol levels',
#  'cholesterol-lowering benefits',
#  'increase “bad” LDL-cholesterol',
#  'increase HDL',
#  'Excess cholesterol',
#  'abnormal cholesterol',
#  'High cholesterol foods',
#  'decreases low-density lipoprotein',
#  'total cholesterol levels in the blood',
#  'reduces blood levels of bad cholesterol',
#  'increasing levels of good cholesterol',
#  'decreased the level of LDL cholesterol',
#  'cholesterol levels',
#  'low-density lipoprotein [LDL]',
#  'foods rich in cholesterol',
#  'increase the levels of cholesterol',
#  'cholesterol blood test',
#  'fat (cholesterol)',
#  'total cholesterol level',
#  'reduce blood cholesterol',
#  'Cholesterol',
#  'lower your cholesterol levels',
#  'lowering blood cholesterol',
#  'Unhealthy cholesterol',
#  'Controls cholesterol',
#  'cholesterol-reducing',
#  'lowering LDL cholesterol',
#  'raising HDL cholesterol',
#  'High LDL cholesterol',
#  'Improves Cholesterol Levels',
#  'cholesterol lowering properties',
#  'dyslipidaemia',
#  'lowering cholesterol level',
#  'raises the HDL cholesterol levels',
#  'control your cholesterol',
#  'high in cholesterol',
#  'cholesterol test',
#  'reduce cholesterol levels',
#  'reduces both low-density lipoprotein (LDL)',
#  'increasing high-density lipoprotein (HDL) levels',
#  'treatment of high cholesterol',
#  '“bad” cholesterol',
#  'help reduce cholesterol',
#  'cut bad cholesterol',
#  'balance cholesterol levels',
#  'get cholesterol from the food you eat',
#  'reduce "unhealthy" LDL cholesterol',
#  'boost "healthy" HDL cholesterol',
#  "lower levels of 'bad' LDL cholesterol",
#  "increase 'good' HDL cholesterol levels",
#  'reduces levels of bad cholesterol',
#  'raise your HDL (good) cholesterol',
#  'boost your HDL levels',
#  'lowering blood cholesterol levels',
#  'foods with high cholesterol',
#  'help lower their cholesterol',
#  'control blood-cholesterol levels',
#  'drop in their LDL',
#  'keep the cholesterol levels healthy',
#  'bring your bad (LDL) cholesterol down',
#  'Hyperlipidemia',
#  'maintain the healthy levels of cholesterol',
#  'high blood fats',
#  'high levels of certain blood fats',
#  'total cholesterol number',
#  'reducing blood cholesterol levels',
#  'help lower cholesterol levels',
#  'decreases the amount of cholesterol',
#  'break down cholesterol',
#  'raise HDL (good cholesterol)',
#  'lower LDL',
#  'blood cholesterol test',
#  'keeps your cholesterol levels in check',
#  'raise LDL cholesterol',
#  'lower bad-guy LDLs',
#  'reduce the level of cholesterol',
#  'reduce bad LDL cholesterol',
#  'increase good HDL levels',
#  'increase good HDL cholesterol levels',
#  'control high cholesterol levels',
#  'cholesterol testing',
#  'increase your cholesterol',
#  'high blood cholesterol levels',
#  'high blood cholesterol',
#  'cholesterol-lowering properties',
#  "lower 'bad' cholesterol",
#  'reduction in low-density lipoprotein',
#  'LDL (bad) blood cholesterol',
#  'decreasing LDL',
#  'bad cholesterol level',
#  'LDL lipoprotein',
#  'treatment for high cholesterol',
#  'cholesterol screening',
#  'help lower blood cholesterol',
#  'LDL measurements',
#  'lowers cholesterol levels',
#  'lower levels of LDL cholesterol',
#  'cholesterol tests',
#  'lowers blood cholesterol',
#  'Total cholesterol',
#  'total blood cholesterol',
#  'increase HDL cholesterol',
#  'lower your LDL cholesterol',
#  'raise your HDL cholesterol',
#  'boost your HDL level',
#  'cut your LDL (bad) cholesterol levels',
#  'reduce the cholesterol levels',
#  'High cholesterol levels',
#  'control your cholesterol levels',
#  'lower in cholesterol',
#  'Cholesterol tests',
#  'reduce your LDL cholesterol',
#  'low-density lipoprotein (LDL) cholesterol',
#  'Fighting cholesterol',
#  'bad cholesterol (LDL)',
#  'increase your HDL cholesterol levels',
#  'increase HDL cholesterol levels',
#  'chol',
#  'High HDL',
#  'Low-density lipoprotein particle',
#  'LDL-C',
#  'low-density lipoprotein cholesterol',
#  'cholesterol level',
#  'helps lower cholesterol',
#  'LDL ( bad cholesterol )',
#  'increase HDL ( good cholesterol )',
#  'blood lipid test',
#  'LDL (low-density lipoprotein) cholesterol',
#  'modify cholesterol levels',
#  'raise HDL cholesterol',
#  'treat high levels of cholesterol',
#  'High levels of HDL cholesterol',
#  'total cholesterol measurement',
#  'boost HDL cholesterol levels',
#  'cholesterol level in blood',
#  'lower low density lipoprotein (LDL)',
#  'bad cholesterol levels',
#  'LDL (low density lipoprotein)',
#  'reduce total cholesterol',
#  'bad low-density lipoprotein (LDL) cholesterol',
#  'increase good high-density lipoprotein (HDL) cholesterol',
#  'low cholesterol diet',
#  'Lipid disorder',
#  'increased cholesterol level',
#  'very high levels of cholesterol in the blood',
#  'cholesterol controlling',
#  'elevated or abnormal levels of lipids',
#  'blood test that measures lipids',
#  'Total cholesterol level',
#  'reduction of cholesterol levels',
#  'moderating cholesterol',
#  'used to lower cholesterol levels',
#  'low density lipoprotein',
#  'Cholesterol support',
#  'raise your cholesterol levels',
#  'increase your HDL counts',
#  'Lowers LDL cholesterol levels',
#  'blood cholesterol levels that are too high',
#  'help to lower your cholesterol',
#  'help lower your cholesterol level',
#  'reduce high cholesterol',
#  'promote good cholesterol',
#  'higher LDL cholesterol level',
#  'contribute “good” cholesterol',
#  'rid it of “bad” cholesterol',
#  'high HDL cholesterol',
#  'cholesterol in the food you eat',
#  'increase cholesterol levels',
#  'lower your blood cholesterol level',
#  'LDL (Low Density Lipoprotein or bad cholesterol)',
#  'reduce bad cholesterol in the blood',
#  'improve good cholesterol levels',
#  'foods low in cholesterol',
#  'lower total cholesterol levels',
#  'lowering the level of bad LDL cholesterol',
#  'increase the level of good HDL cholesterol',
#  'healthy cholesterol levels',
#  'high amount of cholesterol',
#  'control blood cholesterol levels',
#  'lowered cholesterol',
#  'reducing low-density lipoprotein',
#  'LDL, or bad, cholesterol',
#  'presence of excess cholesterol in the blood',
#  'helps lower blood cholesterol level',
#  'reducing bad cholesterol levels',
#  'lowering the level of bad cholesterol',
#  'raise bad cholesterol',
#  'improving cholesterol levels',
#  'cholesterol reduction',
#  'LDL cholesterol level (bad cholesterol)',
#  'High fat levels in the blood',
#  'increase the level of "good" cholesterol',
#  'lowering "bad" cholesterol',
#  'fat-like substance cholesterol',
#  'lowers low-density lipoprotein (LDL or bad) cholesterol',
#  'increasing high-density lipoprotein (HDL or good) cholesterol',
#  'lowering of your cholesterol levels',
#  'low in cholesterol',
#  'LDL cholesterol values',
#  'reduce the level of low-density lipoprotein (LDL) cholesterol',
#  'reduction in the cholesterol levels',
#  'LDL (the bad cholesterol)',
#  'lowers bad LDL cholesterol',
#  'very little cholesterol',
#  'reduce bad cholesterol levels',
#  'Cholesterol testing',
#  'reducing the bad cholesterol (low-density lipoprotein)',
#  'raise good cholesterol',
#  'a blood test that measures lipids',
#  'having high cholesterol',
#  'Raise Your Good Cholesterol Levels',
#  'raising your HDL',
#  'raise HDL',
#  'foods that are high in cholesterol',
#  'lower bad cholesterol (LDL)',
#  'lower blood cholesterol concentrations',
#  'Cholesterol screenings',
#  'high colestrol',
#  'increasing your cholesterol levels',
#  'helps lower the total amount of cholesterol in the blood',
#  'raise your good cholesterol',
#  'increasing your LDL cholesterol',
#  'higher HDL',
#  'high levels of bad cholesterol',
#  'raise blood levels of LDL',
#  'maintain healthy cholesterol levels',
#  'reduce levels of bad cholesterol',
#  'increase levels of good cholesterol',
#  'remove cholesterol from your blood',
#  'high cholesterol level',
#  'cholesterol is very low',
#  'potential to lower cholesterol',
#  "boost 'good' cholesterol",
#  'increase high-density lipoprotein (HDL) cholesterol',
#  'lower high cholesterol levels',
#  'controlling Cholesterol',
#  'very significantly elevated low-density lipoprotein (LDL) cholesterol',
#  'cholesterol-lowering effects',
#  'remove bad cholesterol',
#  'high amounts of cholesterol',
#  'cut LDL cholesterol levels',
#  'help improve your cholesterol levels',
#  'LDL or bad cholesterol',
#  'lowers LDL cholesterol',
#  'LDL (Bad Cholesterol)',
#  'reduction of bad cholesterol',
#  'high level of high-density lipoprotein cholesterol',
#  'reduce cholesterol in the blood',
#  'lowers cholesterol in the blood',
#  'lowers the LDL-C',
#  'raise your HDL-C',
#  'total cholesterol panel',
#  'reduction of cholesterol',
#  'help with managing cholesterol',
#  'reduces your low-density lipoprotein (LDL)',
#  'high cholestrol',
#  'raise your LDL cholesterol',
#  'boost your HDL or “good” cholesterol']

# %% [markdown]
# ### Class cluster

# %%
#| export
class Cluster:

    @staticmethod
    def from_similarity(lbl_lbl:sp.csr_matrix, score_thresh:Optional[float]=0.3, diff_thresh:Optional[float]=0.2, 
                        sim_topk:Optional[int]=20):
        lbl_lbl = retain_topk(lbl_lbl, k=sim_topk)
        lbl_lbl = Operations.min_clamp(lbl_lbl, score_thresh)
        lbl_lbl = Operations.diff_threshold(lbl_lbl, diff_thresh)
        
        n, groups = sp.csgraph.connected_components(lbl_lbl)
        return Operations.get_clusters(groups)

    @staticmethod
    def from_predictions(data_lbl:sp.csr_matrix, score_thresh:Optional[float]=0.3, diff_thresh:Optional[float]=0.2, 
                         pred_topk:Optional[int]=3):
        data_lbl = retain_topk(data_lbl, k=pred_topk)
        data_lbl = Operations.min_clamp(data_lbl, score_thresh)
        data_lbl = Operations.diff_threshold(data_lbl, diff_thresh)
        
        lbl_mat = Operations.compute_yty(data_lbl.transpose())
        n, groups = sp.csgraph.connected_components(lbl_mat)
        return Operations.get_clusters(groups)

    @staticmethod
    def from_derived_phrases(lbl_phrases:sp.csr_matrix):
        lbl_mat = Operations.compute_yty(lbl_phrases)
        n, groups = sp.csgraph.connected_components(lbl_mat)
        return Operations.get_clusters(groups)

# %% [markdown]
# ## `Conflation`

# %%
#| export
class Conflation:

    @staticmethod
    def get_groups(clusters:List, n_lbl:int):
        groups = np.full(n_lbl, -1)
        for i,idx in enumerate(clusters):
            groups[idx] = i
        idxs = np.where(groups == -1)[0]
        groups[idxs] = np.arange(len(clusters), len(clusters) + idxs.shape[0])
        return groups

    @staticmethod
    def get_conflated_matrix(matrix:sp.csr_matrix, groups:np.array, n_lbl:Optional[int]=None):
        data, indptr = matrix.data, matrix.indptr
        indices = [groups[i] for i in matrix.indices]
        shape = None if n_lbl is None else (matrix.shape[0], n_lbl)
        return sp.csr_matrix((data, indices, indptr), shape=shape)

    @staticmethod
    def get_conflated_info(clusters:List, info:Dict):
        conflated_info, flag, lbl_idx = dict(), np.zeros(len(info["identifier"])), []
        
        for idxs in clusters:
            idx = np.random.choice(idxs)
            conflated_info.setdefault("identifier", []).append(info["identifier"][idx])
            conflated_info.setdefault("text", []).append(info["text"][idx])
            lbl_idx.append(idx)
            flag[idxs] = 1
            
        idxs = np.where(flag == 0)[0]
        for idx in idxs:
            conflated_info.setdefault("identifier", []).append(info["identifier"][idx])
            conflated_info.setdefault("text", []).append(info["text"][idx])
            lbl_idx.append(idx)
            flag[idx] = 1
            
        assert flag.all(), "All items should be covered."
        return conflated_info, lbl_idx

    @staticmethod
    def perform_conflation(clusters:List, trn_meta:sp.csr_matrix, meta_info:Dict, tst_meta:Optional[sp.csr_matrix]=None, 
                           lbl_meta:Optional[sp.csr_matrix]=None):
        
        groups = Conflation.get_groups(clusters, n_lbl=trn_meta.shape[1])

        conflated_trn_meta = Conflation.get_conflated_matrix(trn_meta, groups)
        conflated_meta_info, meta_idx = Conflation.get_conflated_info(clusters, meta_info)
        
        conflated_tst_meta = None if tst_meta is None else Conflation.get_conflated_matrix(tst_meta, groups, n_lbl=conflated_trn_meta.shape[1])
        conflated_lbl_meta = None if lbl_meta is None else Conflation.get_conflated_matrix(lbl_meta, groups, n_lbl=conflated_trn_meta.shape[1])

        return conflated_trn_meta, conflated_meta_info, meta_idx, conflated_tst_meta, conflated_lbl_meta

# %% [markdown]
# ### Derived phrase `+` semantic conflation

# %%
clusters = Cluster.from_derived_phrases(meta_phrases)
# Out:
#   0%|          | 0/1658 [00:00<?, ?it/s]

# %%
clusters = Filter.remove_top_clusters(clusters, topk=1)

# %%
ctrn_meta, cmeta_info, meta_idx, ctst_meta, _ = Conflation.perform_conflation(clusters, trn_meta, meta_info, tst_meta=tst_meta)

# %%
meta_file = f"{linker_dir}/test_predictions_labels_msmarco-distilbert-cos-v5.npz"
meta_mat = retain_topk(sp.load_npz(meta_file), k=10)

# %%
meta_mat = meta_mat[meta_idx][:, meta_idx]

# %%
clusters = Cluster.from_similarity(meta_mat, score_thresh=0.5, diff_thresh=0.2, sim_topk=10)

# %%
clusters = Filter.remove_top_clusters(clusters, topk=1)

# %%
ctrn_meta, cmeta_info, meta_idx, ctst_meta, _ = Conflation.perform_conflation(clusters, ctrn_meta, cmeta_info, tst_meta=ctst_meta)

# %%
ctrn_meta.getnnz(axis=0).mean()
# Out:
# np.float64(1.8354457163056375)

# %% [markdown]
# ### Semantic conflation

# %%
meta_file = f"{linker_dir}/test_predictions_labels_msmarco-distilbert-cos-v5.npz"
meta_mat = retain_topk(sp.load_npz(meta_file), k=10)

# %%
clusters = Cluster.from_similarity(meta_mat, score_thresh=0.5, diff_thresh=0.2, sim_topk=10)

# %%
clusters = Filter.remove_top_clusters(clusters, topk=1)

# %%
ctrn_meta, cmeta_info, meta_idx, ctst_meta, _ = Conflation.perform_conflation(clusters, trn_meta, meta_info, tst_meta=tst_meta)

# %%
ctrn_meta.getnnz(axis=0).mean()
# Out:
# np.float64(1.6394842156736276)

# %%
ctrn_meta
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 2186003 stored elements and shape (502939, 1333348)>

# %% [markdown]
# ## `Save data`

# %%
#| export
class SaveData:

    @staticmethod
    def save_raw(fname:str, ids:List, txt:List):
        df = pd.DataFrame({"identifier": ids, "text": txt})
        df.to_csv(fname, index=False)

    @staticmethod
    def proc(save_dir:str, trn_file:str, trn_meta:sp.csr_matrix, info_file:str, meta_info:Dict, 
             tst_file:Optional[str]=None, tst_meta:Optional[sp.csr_matrix]=None, lbl_file:Optional[str]=None, 
             lbl_meta:Optional[sp.csr_matrix]=None):
        
        n = len([o for o in os.listdir(save_dir) if re.match(r'conflation_[0-9]{2}', o)]) + 1
        save_dir = f"{save_dir}/conflation_{n:02d}"
        
        raw_dir = f"{save_dir}/raw_data"
        os.makedirs(raw_dir, exist_ok=True)

        sp.save_npz(f"{save_dir}/{os.path.basename(trn_file)}", trn_meta)
        
        if tst_meta is not None:
            sp.save_npz(f"{save_dir}/{os.path.basename(tst_file)}", tst_meta)
            
        if lbl_meta is not None:
            sp.save_npz(f"{save_dir}/{os.path.basename(lbl_file)}", lbl_meta)

        raw_file = f"{raw_dir}/{os.path.basename(info_file)}"
        SaveData.save_raw(raw_file, meta_info["identifier"], meta_info["text"])

# %% [markdown]
# ## Driver

# %%
data_dir = "/Users/suchith720/Projects/data/beir/msmarco/XC/substring/"

trn_file = f"{data_dir}/substring_trn_X_Y.npz"
tst_file = f"{data_dir}/substring_tst_X_Y.npz"
info_file = f"{data_dir}/raw_data/substring.raw.csv"

trn_meta, tst_meta = sp.load_npz(trn_file), sp.load_npz(tst_file)
meta_info = pd.read_csv(info_file)

meta_phrases = sp.load_npz(f"{data_dir}/derived-phrases_substring_X_Y.npz")

# %%
linker_dir = "/Users/suchith720/Downloads/00_msmarco-gpt-concept-substring-linker-with-ngame-loss-001/"

# %%
clusters = Cluster.from_derived_phrases(meta_phrases)
# Out:
#   0%|          | 0/1658 [00:00<?, ?it/s]

# %%
clusters = Filter.remove_top_clusters(clusters, topk=1)

# %%
ctrn_meta, cmeta_info, meta_idx, ctst_meta = Conflation.perform_conflation(clusters, trn_meta, meta_info, tst_meta)

# %%
meta_file = f"{linker_dir}/test_predictions_labels_msmarco-distilbert-cos-v5.npz"
meta_mat = retain_topk(sp.load_npz(meta_file), k=10)

# %%
meta_mat = meta_mat[meta_idx][:, meta_idx]

# %%
clusters = Cluster.from_similarity(meta_mat, score_thresh=0.7, diff_thresh=0.2, sim_topk=20)

# %%
clusters = Filter.remove_top_clusters(clusters, topk=1)

# %%
ctrn_meta, cmeta_info, meta_idx, ctst_meta = Conflation.perform_conflation(clusters, ctrn_meta, cmeta_info, ctst_meta)

# %%
ctrn_meta.getnnz(axis=0).mean()
# Out:
# np.float64(1.9417916334300378)
